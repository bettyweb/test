# %% [markdown]
# # Capstone Project Notebook

# %% [markdown]
# ## This notebook will be mainly used for the Coursera course: Applied DataScience Capstone

# %% [markdown]
# In the line below I just execute simple code. I only print "Hello World".

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
y = "Hello Capstone Project Course!"
print (y)
# Out:
# Hello Capstone Project Course!
